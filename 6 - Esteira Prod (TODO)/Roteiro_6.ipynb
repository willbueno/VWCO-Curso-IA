# %% [markdown]
# <a href="https://colab.research.google.com/github/TreinamentoICCInatel/CursoVW/blob/main/Esteira%20Prod/Roteiro_6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Roteiro 6**
# ### **Produção**
#
# Usar as células abaixo para executar os comandos do arquivo: roteiro6.docx

# %%
#Comece os códigos aqui!
