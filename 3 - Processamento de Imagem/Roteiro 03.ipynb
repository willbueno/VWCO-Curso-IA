# %% [markdown]
# <a href="https://colab.research.google.com/github/willbueno/VWCO-Curso-IA/blob/main/Processamento%20de%20Imagem/Roteiro%2003.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Roteiro Processamento de Imagens**
# ## Utilizar este Notebook para executar os comandos.
# **Arquivo de referência:** *Roteiro Processamento de Imagens.docx*
