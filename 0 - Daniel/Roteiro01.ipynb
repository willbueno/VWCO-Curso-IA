# %% [markdown]
# # **Roteiro EDA**
# ## Utilizar este Notebook para executar os comandos.
# **Arquivo de referência:** *Roteiro EDA.docx*

# %%
import pandas as pd

# %%
data = 'https://raw.githubusercontent.com/rlrocha90/CursoVW/refs/heads/main/EDA/Auto%20Sales%20data.csv'

# %%
df = pd.read_csv(data)

# %%
df.head()
# Out:
#    ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0        10107               30      95.70                2  2871.00
# 1        10121               34      81.35                5  2765.90
# 2        10134               41      94.74                2  3884.34
# 3        10145               45      83.26                6  3746.70
# 4        10168               36      96.66                1  3479.76
#
#     ORDERDATE  DAYS_SINCE_LASTORDER   STATUS  PRODUCTLINE  MSRP PRODUCTCODE  \
# 0  24/02/2018                   828  Shipped  Motorcycles    95    S10_1678
# 1  07/05/2018                   757  Shipped  Motorcycles    95    S10_1678
# 2  01/07/2018                   703  Shipped  Motorcycles    95    S10_1678
# 3  25/08/2018                   649  Shipped  Motorcycles    95    S10_1678
# 4  28/10/2018                   586  Shipped  Motorcycles    95    S10_1678
#
#            CUSTOMERNAME             PHONE                   ADDRESSLINE1  \
# ...

# %%
pd.unique(df['STATUS'])
# Out:
# array(['Shipped', 'Disputed', 'In Process', 'Cancelled', 'On Hold',
#        'Resolved'], dtype=object)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2747 entries, 0 to 2746
# Data columns (total 20 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   ORDERNUMBER           2747 non-null   int64
#  1   QUANTITYORDERED       2747 non-null   int64
#  2   PRICEEACH             2747 non-null   float64
#  3   ORDERLINENUMBER       2747 non-null   int64
#  4   SALES                 2747 non-null   float64
#  5   ORDERDATE             2747 non-null   object
#  6   DAYS_SINCE_LASTORDER  2747 non-null   int64
#  7   STATUS                2747 non-null   object
#  8   PRODUCTLINE           2747 non-null   object
#  9   MSRP                  2747 non-null   int64
#  10  PRODUCTCODE           2747 non-null   object
#  11  CUSTOMERNAME          2747 non-null   object
#  12  PHONE                 2747 non-null   object
#  13  ADDRESSLINE1          2747 non-null   object
#  14  CITY                  2747 non-null   object
# ...

# %%
df.loc[4:10,['SALES','STATUS']]
# Out:
#       SALES   STATUS
# 4   3479.76  Shipped
# 5   2497.77  Shipped
# 6   5512.32  Shipped
# 7   4708.44  Shipped
# 8   3965.66  Shipped
# 9   2333.12  Shipped
# 10  3188.64  Shipped

# %%
df[4:10]
# Out:
#    ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 4        10168               36      96.66                1  3479.76
# 5        10180               29      86.13                9  2497.77
# 6        10188               48     114.84                1  5512.32
# 7        10211               41     114.84               14  4708.44
# 8        10223               37     107.18                1  3965.66
# 9        10237               23     101.44                7  2333.12
#
#     ORDERDATE  DAYS_SINCE_LASTORDER   STATUS  PRODUCTLINE  MSRP PRODUCTCODE  \
# 4  28/10/2018                   586  Shipped  Motorcycles    95    S10_1678
# 5  11/11/2018                   573  Shipped  Motorcycles    95    S10_1678
# 6  18/11/2018                   567  Shipped  Motorcycles    95    S10_1678
# 7  15/01/2019                   510  Shipped  Motorcycles    95    S10_1678
# 8  20/02/2019                   475  Shipped  Motorcycles    95    S10_1678
# ...

# %%
df.loc[4]
# Out:
# ORDERNUMBER                            10168
# QUANTITYORDERED                           36
# PRICEEACH                              96.66
# ORDERLINENUMBER                            1
# SALES                                3479.76
# ORDERDATE                         28/10/2018
# DAYS_SINCE_LASTORDER                     586
# STATUS                               Shipped
# PRODUCTLINE                      Motorcycles
# MSRP                                      95
# PRODUCTCODE                         S10_1678
# CUSTOMERNAME            Technics Stores Inc.
# PHONE                             6505556809
# ADDRESSLINE1               9408 Furth Circle
# CITY                              Burlingame
# POSTALCODE                             94217
# COUNTRY                                  USA
# CONTACTLASTNAME                       Hirano
# CONTACTFIRSTNAME                        Juri
# DEALSIZE                              Medium
# Name: 4, dtype: object

# %%
df.describe()
# Out:
#         ORDERNUMBER  QUANTITYORDERED    PRICEEACH  ORDERLINENUMBER  \
# count   2747.000000      2747.000000  2747.000000      2747.000000
# mean   10259.761558        35.103021   101.098952         6.491081
# std       91.877521         9.762135    42.042549         4.230544
# min    10100.000000         6.000000    26.880000         1.000000
# 25%    10181.000000        27.000000    68.745000         3.000000
# 50%    10264.000000        35.000000    95.550000         6.000000
# 75%    10334.500000        43.000000   127.100000         9.000000
# max    10425.000000        97.000000   252.870000        18.000000
#
#               SALES  DAYS_SINCE_LASTORDER         MSRP
# count   2747.000000           2747.000000  2747.000000
# mean    3553.047583           1757.085912   100.691664
# std     1838.953901            819.280576    40.114802
# min      482.130000             42.000000    33.000000
# 25%     2204.350000           1077.000000    68.000000
# ...

# %%
pd.unique(df['STATUS'])
# Out:
# array(['Shipped', 'Disputed', 'In Process', 'Cancelled', 'On Hold',
#        'Resolved'], dtype=object)

# %%
df.select_dtypes(include=[object]).describe()
# Out:
#          ORDERDATE   STATUS   PRODUCTLINE PRODUCTCODE           CUSTOMERNAME  \
# count         2747     2747          2747        2747                   2747
# unique         246        6             7         109                     89
# top     14/11/2018  Shipped  Classic Cars    S18_3232  Euro Shopping Channel
# freq            38     2541           949          51                    259
#
#                  PHONE        ADDRESSLINE1    CITY POSTALCODE COUNTRY  \
# count             2747                2747    2747       2747    2747
# unique              88                  89      71         73      19
# top     (91) 555 94 44  C/ Moralzarzal, 86  Madrid      28034     USA
# freq               259                 259     304        259     928
#
#        CONTACTLASTNAME CONTACTFIRSTNAME DEALSIZE
# count             2747             2747     2747
# unique              76               72        3
# top             Freyre            Diego   Medium
# ...

# %%
df.select_dtypes(include=[object]).describe().T
# Out:
#                  count unique                    top  freq
# ORDERDATE         2747    246             14/11/2018    38
# STATUS            2747      6                Shipped  2541
# PRODUCTLINE       2747      7           Classic Cars   949
# PRODUCTCODE       2747    109               S18_3232    51
# CUSTOMERNAME      2747     89  Euro Shopping Channel   259
# PHONE             2747     88         (91) 555 94 44   259
# ADDRESSLINE1      2747     89     C/ Moralzarzal, 86   259
# CITY              2747     71                 Madrid   304
# POSTALCODE        2747     73                  28034   259
# COUNTRY           2747     19                    USA   928
# CONTACTLASTNAME   2747     76                 Freyre   259
# CONTACTFIRSTNAME  2747     72                  Diego   259
# DEALSIZE          2747      3                 Medium  1349

# %%
df['PRICEEACH'].to_numpy()
# Out:
# array([ 95.7 ,  81.35,  94.74, ..., 125.99,  62.24,  65.52])

# %%
column = df['PRICEEACH'].to_numpy()

# %%
import matplotlib.pyplot as plt

# %%
N = len(column)

# %%
N
# Out:
# 2747

# %%
range(N)
# Out:
# range(0, 2747)

# %%
N = len(column)
plt.scatter(range(N), column)
plt.xlabel('Faixa de 1 a 2747')
plt.ylabel('Preço de Cada Pedido')
plt.title('Gráfico de Preço de Cada Pedido')
plt.show()

# %%
column1 = df['SALES'].to_numpy()

# %%
N1 = len(column1)

# %%
N = len(column1)
plt.scatter(range(N1), column1)
plt.xlabel('Faixa de 1 a 2747')
plt.ylabel('Total de Vendas')
plt.title('Gráfico de Vendas')
plt.show()

# %%
df.sort_values('DAYS_SINCE_LASTORDER')
# Out:
#       ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER     SALES  \
# 23          10417               66     113.88                2   7516.08
# 49          10424               50     240.02                6  12001.00
# 22          10403               24     101.44                7   2434.56
# 48          10411               23     180.01                9   4140.23
# 73          10417               45     130.83                5   5887.35
# ...           ...              ...        ...              ...       ...
# 2642        10105               22     116.19                7   2556.18
# 2722        10117               50      43.68                2   2184.00
# 2668        10106               48      61.44               10   2949.12
# 2695        10106               48      52.64               15   2526.72
# 2721        10105               25      56.78                8   1419.50
#
#        ORDERDATE  DAYS_SINCE_LASTORDER      STATUS   PRODUCTLINE  MSRP  \
# ...

# %%
df.sort_values('DAYS_SINCE_LASTORDER', ascending=False)
# Out:
#       ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER     SALES  \
# 2721        10105               25      56.78                8   1419.50
# 2695        10106               48      52.64               15   2526.72
# 2668        10106               48      61.44               10   2949.12
# 2722        10117               50      43.68                2   2184.00
# 2642        10105               22     116.19                7   2556.18
# ...           ...              ...        ...              ...       ...
# 73          10417               45     130.83                5   5887.35
# 48          10411               23     180.01                9   4140.23
# 22          10403               24     101.44                7   2434.56
# 49          10424               50     240.02                6  12001.00
# 23          10417               66     113.88                2   7516.08
#
#        ORDERDATE  DAYS_SINCE_LASTORDER      STATUS   PRODUCTLINE  MSRP  \
# ...

# %%
df.sort_values('PRICEEACH')['PRICEEACH']
# Out:
# 1509     26.88
# 1666     28.29
# 1497     28.88
# 1495     29.21
# 1492     29.21
#          ...
# 176     245.20
# 178     245.20
# 25      248.59
# 714     250.73
# 1507    252.87
# Name: PRICEEACH, Length: 2747, dtype: float64

# %%
column2 = df.sort_values('PRICEEACH')['PRICEEACH'].to_numpy()

# %%
N = len(column2)
plt.scatter(range(N), column2)
plt.xlabel('Faixa de 1 a 2747')
plt.ylabel('Preço de Cada Pedido')
plt.title('Gráfico de Preço de Cada Pedido')
plt.show()

# %%
df['NOVO'] = df['PRICEEACH']*10

# %%
df
# Out:
#       ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0           10107               30      95.70                2  2871.00
# 1           10121               34      81.35                5  2765.90
# 2           10134               41      94.74                2  3884.34
# 3           10145               45      83.26                6  3746.70
# 4           10168               36      96.66                1  3479.76
# ...           ...              ...        ...              ...      ...
# 2742        10350               20     112.22               15  2244.40
# 2743        10373               29     137.19                1  3978.51
# 2744        10386               43     125.99                4  5417.57
# 2745        10397               34      62.24                1  2116.16
# 2746        10414               47      65.52                9  3079.44
#
#        ORDERDATE  DAYS_SINCE_LASTORDER    STATUS  PRODUCTLINE  MSRP  ...  \
# ...

# %%
from datetime import datetime

# %%
temp_date = datetime(2025,11,14)

# %%
print(temp_date)
# Out:
# 2025-11-14 00:00:00

# %%
df['ORDERDATE'] = pd.to_datetime(df['ORDERDATE'])
df['ORDERDATE']
# Out:
# 0      2018-02-24
# 1      2018-05-07
# 2      2018-07-01
# 3      2018-08-25
# 4      2018-10-28
#           ...
# 2742   2019-12-02
# 2743   2020-01-31
# 2744   2020-03-01
# 2745   2020-03-28
# 2746   2020-05-06
# Name: ORDERDATE, Length: 2747, dtype: datetime64[ns]

# %%
df['DAYS_SINCE_LASTORDER_3'] = (temp_date - df['ORDERDATE']).dt.days

# %%
df
# Out:
#       ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0           10107               30      95.70                2  2871.00
# 1           10121               34      81.35                5  2765.90
# 2           10134               41      94.74                2  3884.34
# 3           10145               45      83.26                6  3746.70
# 4           10168               36      96.66                1  3479.76
# ...           ...              ...        ...              ...      ...
# 2742        10350               20     112.22               15  2244.40
# 2743        10373               29     137.19                1  3978.51
# 2744        10386               43     125.99                4  5417.57
# 2745        10397               34      62.24                1  2116.16
# 2746        10414               47      65.52                9  3079.44
#
#       ORDERDATE  DAYS_SINCE_LASTORDER    STATUS  PRODUCTLINE  MSRP  ...  \
# ...

# %%
df.drop(['DAYS_SINCE_LASTORDER_3'], axis=1, inplace=True)

# %%
df
# Out:
#       ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0           10107               30      95.70                2  2871.00
# 1           10121               34      81.35                5  2765.90
# 2           10134               41      94.74                2  3884.34
# 3           10145               45      83.26                6  3746.70
# 4           10168               36      96.66                1  3479.76
# ...           ...              ...        ...              ...      ...
# 2742        10350               20     112.22               15  2244.40
# 2743        10373               29     137.19                1  3978.51
# 2744        10386               43     125.99                4  5417.57
# 2745        10397               34      62.24                1  2116.16
# 2746        10414               47      65.52                9  3079.44
#
#       ORDERDATE  DAYS_SINCE_LASTORDER    STATUS  PRODUCTLINE  MSRP  ...  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2747 entries, 0 to 2746
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   ORDERNUMBER           2747 non-null   int64
#  1   QUANTITYORDERED       2747 non-null   int64
#  2   PRICEEACH             2747 non-null   float64
#  3   ORDERLINENUMBER       2747 non-null   int64
#  4   SALES                 2747 non-null   float64
#  5   ORDERDATE             2747 non-null   datetime64[ns]
#  6   DAYS_SINCE_LASTORDER  2747 non-null   int64
#  7   STATUS                2747 non-null   object
#  8   PRODUCTLINE           2747 non-null   object
#  9   MSRP                  2747 non-null   int64
#  10  PRODUCTCODE           2747 non-null   object
#  11  CUSTOMERNAME          2747 non-null   object
#  12  PHONE                 2747 non-null   object
#  13  ADDRESSLINE1          2747 non-null   object
#  14  CITY                  2747 non-null   object
# ...

# %%
df_num = df.select_dtypes(include=['float64', 'int64'])

# %%
df_num
# Out:
#       ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0           10107               30      95.70                2  2871.00
# 1           10121               34      81.35                5  2765.90
# 2           10134               41      94.74                2  3884.34
# 3           10145               45      83.26                6  3746.70
# 4           10168               36      96.66                1  3479.76
# ...           ...              ...        ...              ...      ...
# 2742        10350               20     112.22               15  2244.40
# 2743        10373               29     137.19                1  3978.51
# 2744        10386               43     125.99                4  5417.57
# 2745        10397               34      62.24                1  2116.16
# 2746        10414               47      65.52                9  3079.44
#
#       DAYS_SINCE_LASTORDER  MSRP    NOVO
# 0                      828    95   957.0
# ...

# %%
df.isnull()
# Out:
#       ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER  SALES  \
# 0           False            False      False            False  False
# 1           False            False      False            False  False
# 2           False            False      False            False  False
# 3           False            False      False            False  False
# 4           False            False      False            False  False
# ...           ...              ...        ...              ...    ...
# 2742        False            False      False            False  False
# 2743        False            False      False            False  False
# 2744        False            False      False            False  False
# 2745        False            False      False            False  False
# 2746        False            False      False            False  False
#
#       ORDERDATE  DAYS_SINCE_LASTORDER  STATUS  PRODUCTLINE   MSRP  ...  \
# ...

# %%
df.isnull().sum()
# Out:
# ORDERNUMBER             0
# QUANTITYORDERED         0
# PRICEEACH               0
# ORDERLINENUMBER         0
# SALES                   0
# ORDERDATE               0
# DAYS_SINCE_LASTORDER    0
# STATUS                  0
# PRODUCTLINE             0
# MSRP                    0
# PRODUCTCODE             0
# CUSTOMERNAME            0
# PHONE                   0
# ADDRESSLINE1            0
# CITY                    0
# POSTALCODE              0
# COUNTRY                 0
# CONTACTLASTNAME         0
# CONTACTFIRSTNAME        0
# DEALSIZE                0
# NOVO                    0
# dtype: int64

# %%
df.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 2742    False
# 2743    False
# 2744    False
# 2745    False
# 2746    False
# Length: 2747, dtype: bool

# %%
df.describe()
# Out:
#         ORDERNUMBER  QUANTITYORDERED    PRICEEACH  ORDERLINENUMBER  \
# count   2747.000000      2747.000000  2747.000000      2747.000000
# mean   10259.761558        35.103021   101.098952         6.491081
# min    10100.000000         6.000000    26.880000         1.000000
# 25%    10181.000000        27.000000    68.745000         3.000000
# 50%    10264.000000        35.000000    95.550000         6.000000
# 75%    10334.500000        43.000000   127.100000         9.000000
# max    10425.000000        97.000000   252.870000        18.000000
# std       91.877521         9.762135    42.042549         4.230544
#
#               SALES                      ORDERDATE  DAYS_SINCE_LASTORDER  \
# count   2747.000000                           2747           2747.000000
# mean    3553.047583  2019-05-13 21:56:17.211503360           1757.085912
# min      482.130000            2018-01-06 00:00:00             42.000000
# ...

# %%
df.query('PRICEEACH > 124')
# Out:
#       ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 18          10341               41     188.73                9  7737.93
# 24          10103               26     207.87               11  5404.62
# 25          10112               29     248.59                1  7209.11
# 26          10126               38     192.87               11  7329.06
# 27          10140               37     199.30               11  7374.10
# ...           ...              ...        ...              ...      ...
# 2583        10340               29     141.19                6  4094.51
# 2587        10388               50     143.09                3  7154.50
# 2590        10416               41     137.63                3  5642.83
# 2743        10373               29     137.19                1  3978.51
# 2744        10386               43     125.99                4  5417.57
#
#       ORDERDATE  DAYS_SINCE_LASTORDER    STATUS   PRODUCTLINE  MSRP  ...  \
# ...

# %%
df.query('STATUS != "Shipped"')
# Out:
#       ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER     SALES  \
# 23          10417               66     113.88                2   7516.08
# 49          10424               50     240.02                6  12001.00
# 73          10417               45     130.83                5   5887.35
# 97          10417               56     164.61                4   9218.16
# 103         10167               44     134.64                9   5924.16
# ...           ...              ...        ...              ...       ...
# 2726        10167               38      48.59               15   1846.42
# 2733        10248               23      65.52                9   1506.96
# 2740        10327               37      86.74                4   3209.38
# 2744        10386               43     125.99                4   5417.57
# 2746        10414               47      65.52                9   3079.44
#
#       ORDERDATE  DAYS_SINCE_LASTORDER      STATUS   PRODUCTLINE  MSRP  ...  \
# ...

# %%
#Visualização com Pandas

df.plot.bar(x='STATUS')
# Out:
# <Axes: xlabel='STATUS'>

# %%
#Visualização com Pandas

df.loc[1:5, ['PRICEEACH']].plot.pie(subplots=True)
# Out:
# array([<Axes: ylabel='PRICEEACH'>], dtype=object)
