# %% [markdown]
# <a href="https://colab.research.google.com/github/willbueno/VWCO-Curso-IA/blob/main/5%20-%20Modelos%20com%20Imagens/Roteiro_5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Roteiro Modelo com Imagens**
# ## Utilizar este Notebook para executar os comandos.
# **Arquivo de referência:** *Roteiro 05.docx*

# %%
# !pip install ultralytics -q

# %%
# !pip install ipython

# %%
from ultralytics import YOLO
from IPython.display import display, Image

# %% [markdown]
# A YOLO tem o Modo CLI que executa o código e ele fica rodando direto. Já o Modo SDK Python, ele roda e salva os resultados, eu consigo ver o que foi gerado.

# %%
model = YOLO("yolo26n.pt") #Trocar model pelo arquivo do modelo!
results = model.predict(source='/content/meteor.jpg', conf=0.7, save= True)
# Out:
# image 1/1 /content/meteor.jpg: 544x640 1 truck, 58.8ms
# Speed: 4.0ms preprocess, 58.8ms inference, 16.9ms postprocess per image at shape (1, 3, 544, 640)
# Results saved to /content/runs/detect/predict4

# %%
model= YOLO("yolo26n-seg.pt") #Trocar model pelo arquivo do modelo!
results= model.predict(source='meteor.jpg', conf=0.7, save= True)
# Out:
# image 1/1 /content/meteor.jpg: 544x640 1 truck, 26.3ms
# Speed: 2.6ms preprocess, 26.3ms inference, 5.9ms postprocess per image at shape (1, 3, 544, 640)
# Results saved to /content/runs/segment/predict2

# %%
model= YOLO("yolo26n-cls.pt") #Trocar model pelo arquivo do modelo!
results= model.predict(source='meteor.jpg', conf=0.7, save= True)
# Out:
# image 1/1 /content/meteor.jpg: 224x224 recreational_vehicle 0.53, trailer_truck 0.45, moving_van 0.01, passenger_car 0.00, minibus 0.00, 4.1ms
# Speed: 7.2ms preprocess, 4.1ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# Results saved to /content/runs/classify/predict2

# %%
#POSE

model = YOLO("yolo26n-pose.pt") #trocar model pelo arquivo do modelo!
results = model.predict(source='running.jpg', conf=0.7, save=True)
# Out:
# image 1/1 /content/running.jpg: 224x640 5 persons, 67.3ms
# Speed: 1.2ms preprocess, 67.3ms inference, 0.8ms postprocess per image at shape (1, 3, 224, 640)
# Results saved to /content/runs/pose/predict2

# %%
model = YOLO("yolo26n.pt") #trocar model pelo arquivo do modelo!
results = model.predict(source='aerial.jpg', conf=0.7, save=True)
# Out:
# image 1/1 /content/aerial.jpg: 384x640 7 cars, 59.4ms
# Speed: 1.6ms preprocess, 59.4ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to /content/runs/detect/predict5

# %%
model = YOLO("yolo26n-obb.pt") #trocar model pelo arquivo do modelo!
results = model.predict(source='aerial.jpg', conf=0.9, save=True, show_labels=False)
# Out:
# image 1/1 /content/aerial.jpg: 576x1024 1 small vehicle, 65.2ms
# Speed: 3.2ms preprocess, 65.2ms inference, 0.5ms postprocess per image at shape (1, 3, 576, 1024)
# Results saved to /content/runs/obb/predict3

# %%
model = YOLO("yolo26m-obb.pt") #trocar model pelo arquivo do modelo!
results = model.predict(source='aerial.jpg', conf=0.2, save=True, show_labels=False)
# Out:
# image 1/1 /content/aerial.jpg: 576x1024 2 large vehicles, 23 small vehicles, 57.7ms
# Speed: 3.0ms preprocess, 57.7ms inference, 0.4ms postprocess per image at shape (1, 3, 576, 1024)
# Results saved to /content/runs/obb/predict4

# %%
model = YOLO("yolo26x.pt") # trocar model pelo arquivo do modelo!
results = model.predict(source='aerial.jpg', conf=0.1, save=True, show_labels=False)
# Out:
# image 1/1 /content/aerial.jpg: 384x640 10 persons, 20 cars, 3 buss, 3 trucks, 62.2ms
# Speed: 1.6ms preprocess, 62.2ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to /content/runs/detect/predict6

# %%
model = YOLO("yolo26n.pt") # trocar model pelo arquivo do modelo!
results = model.track(source='meteor.mp4', show=True, conf=0.5, save=True)
# Out:
# WARNING ⚠️ Environment does not support cv2.imshow() or PIL Image.show()
#
#
# WARNING ⚠️
# Inference results will accumulate in RAM unless `stream=True` is passed, which can cause out-of-memory errors for large
# sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# video 1/1 (frame 1/525) /content/meteor.mp4: 384x640 3 trucks, 11.0ms
# video 1/1 (frame 2/525) /content/meteor.mp4: 384x640 3 trucks, 11.2ms
# video 1/1 (frame 3/525) /content/meteor.mp4: 384x640 2 trucks, 12.0ms
# video 1/1 (frame 4/525) /content/meteor.mp4: 384x640 3 trucks, 14.2ms
# video 1/1 (frame 5/525) /content/meteor.mp4: 384x640 3 trucks, 12.2ms
# ...

# %% [markdown]
# app.Roboflow.com >> Projects >> Traditional Mode >> Upload (Photo or Video) >> Save and Continue
# > Annotate >> Label MySelf >> Create Categories
#
# O arquivo para utilizar na máquina é ".yaml"
#
# Local para baixar vídeos
# https://www.kaggle.com/datasets/mexwell/bth-trucks-in-aerial-images

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="Ah4vD6jvlpS0BPSYUCvm")
project = rf.workspace("ia-trainning").project("truck-track")
version = project.version(1)
dataset = version.download("yolo26")
# Out:
# ...
# loading Roboflow workspace...
# loading Roboflow project...

# %%
model= YOLO('yolo26n.pt')
results = model.train(data="/content/Truck-Track-1/data.yaml", epochs=50, imgsz=640)
# Out:
# Ultralytics 8.4.14 🚀 Python-3.12.12 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# ...

# %%
model1 = YOLO("/content/runs/detect/train2/weights/best.pt")
results = model.predict("/content/vid_02.mp4")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipython-input-3148604094.py in <cell line: 0>()
#       1 model1= YOLO("/content/runs/detect/train2/weights/best.pt")
# ----> 2 results = model.predict("/content/vid_02.mp4")
#
# /usr/local/lib/python3.12/dist-packages/ultralytics/engine/model.py in predict(self, source, stream, predictor, **kwargs)
#     534         if prompts and hasattr(self.predictor, "set_prompts"):  # for SAM-type models
#     535             self.predictor.set_prompts(prompts)
# --> 536         return self.predictor.predict_cli(source=source) if is_cli else self.predictor(source=source, stream=stream)
#     537
#     538     def track(
#
# /usr/local/lib/python3.12/dist-packages/ultralytics/engine/predictor.py in __call__(self, source, model, stream, *args, **kwargs)
#     223             return self.stream_inference(source, model, *args, **kwargs)
# ...
